# %%
from fastai2.basics           import *
from fastai2.medical.imaging  import *
from fastai2.callback.all import *
from fastai2.vision.all import *

# %%
path = Path('../dicom_input_data/')
train = path/'train/corads6'
train_files = get_dicom_files(train)
train_files
# Out:
# (#101) [Path('../dicom_input_data/train/corads6/1.3.12.2.1107.5.1.4.67089.30000020032608490724900083443.dcm'),Path('../dicom_input_data/train/corads6/1.3.12.2.1107.5.1.4.67089.30000020032608490724900083424.dcm'),Path('../dicom_input_data/train/corads6/1.3.12.2.1107.5.1.4.67089.30000020032608490724900083377.dcm'),Path('../dicom_input_data/train/corads6/1.3.12.2.1107.5.1.4.67089.30000020032608490724900083406.dcm'),Path('../dicom_input_data/train/corads6/1.3.12.2.1107.5.1.4.67089.30000020032608490724900083355.dcm'),Path('../dicom_input_data/train/corads6/1.3.12.2.1107.5.1.4.67089.30000020032608490724900083346.dcm'),Path('../dicom_input_data/train/corads6/1.3.12.2.1107.5.1.4.67089.30000020032608490724900083363.dcm'),Path('../dicom_input_data/train/corads6/1.3.12.2.1107.5.1.4.67089.30000020032608490724900083351.dcm'),Path('../dicom_input_data/train/corads6/1.3.12.2.1107.5.1.4.67089.30000020032608490724900083414.dcm'),Path('../dicom_input_data/train/corads6/1.3.12.2.1107.5.1.4.67089.300000
# ...

# %%
items = get_dicom_files(path, recurse=True)

img = items[15]
dimg = dcmread(img)
dimg.show(scale=False)

# %% [markdown]
#     DataLoader

# %%
dblock = DataBlock(blocks=(ImageBlock, PointBlock),
                   get_items=get_image_files,
                   splitter=RandomSplitter(),
                   get_y=ColReader("label"))


dbunch = dblock.databunch(path, path=path, bs=24)
dbunch.show_batch(max_n=9, figsize=(9,6))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-de0595cf3008> in <module>
#       5
#       6
# ----> 7 dbunch = dblock.databunch(path, path=path, bs=24)
#       8 dbunch.show_batch(max_n=9, figsize=(9,6))
#
# AttributeError: 'DataBlock' object has no attribute 'databunch'

# %%
# !ls
# Out:
#  1106_Meeting.ipynb	   'fastai2 modelling.ipynb'	 ResNet34.ipynb
#  2606_Meeting.ipynb	   'medical fastai2 EDA.ipynb'
# 'CT - EfficientNet.ipynb'   ResNet34-Copy1.ipynb

# %%
pneumonia = DataBlock(blocks=(ImageBlock(cls=PILDicom), CategoryBlock),
get_x=lambda x:path/f"{x[0]}.dcm",
get_y=lambda x:x[5],
splitter=RandomSplitter(),
batch_tfms=aug_transforms(size=16))

# %%
dls = pneumonia.dataloaders(train_files, bs=16)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-aad7598fa0ae> in <module>
# ----> 1 dls = pneumonia.dataloaders(train_files, bs=16)
#
# ~/miniconda3/lib/python3.7/site-packages/fastai2/data/block.py in dataloaders(self, source, path, verbose, **kwargs)
#     105
#     106     def dataloaders(self, source, path='.', verbose=False, **kwargs):
# --> 107         dsets = self.datasets(source)
#     108         kwargs = {**self.dls_kwargs, **kwargs, 'verbose': verbose}
#     109         return dsets.dataloaders(path=path, after_item=self.item_tfms, after_batch=self.batch_tfms, **kwargs)
#
# ~/miniconda3/lib/python3.7/site-packages/fastai2/data/block.py in datasets(self, source, verbose)
#     102         splits = (self.splitter or RandomSplitter())(items)
#     103         pv(f"{len(splits)} datasets of sizes {','.join([str(len(s)) for s in splits])}", verbose)
# ...

# %%
train_files
# Out:
# (#0) []

# %%
get_y=compose(parent_label,lbl_tfm.__getitem__) or get_y=[parent_label,lbl_tfm.__getitem__]
get_y=ColReader("label")

# %% [markdown]
# ### After learn

# %%
doc(ImageClassifierCleaner) #https://forums.fast.ai/t/imageclassifiercleaner/75312/5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-b569d9e19029> in <module>
#       1 from fastai2.callback.all import *
# ----> 2 doc(ImageClassifierCleaner)
#
# NameError: name 'ImageClassifierCleaner' is not defined
